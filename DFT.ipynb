# %% [markdown]
# <a href="https://colab.research.google.com/github/midorij347/FourierAnalysis/blob/main/DFT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

vectors_num = 100
kyusu = 1000
A = 1
w = 1/50
a = np.zeros(vectors_num)
c = np.zeros(vectors_num)
for i in range(len(a)):
    a[i] = np.pi**2 /6
    for n in range(1,kyusu+1):
      #a[i] = a[i] + (-1)**(n+1) * 1/n * np.sin(n*w*i) * 2*A/np.pi
      a[i] = a[i] + ((-1)**(n+1) * 1/n * np.sin(n*w*np.pi*i) * np.pi**2 + ((-1)**n - 1)*np.sin(np.pi*w*n*i)*2/(n**3) + 2*np.pi* np.cos(n*np.pi*w*i)*(-1)**n /n**2) /np.pi
c = np.arange(0,100,1)
c = c**2/250
plt.plot(a)
plt.plot(c)
plt.show()

# %%
x = np.arange(0,5,0.1)
y = np.sin(x)
plt.plot(a)
plt.show()
